# %% [markdown]
# # Regrid between rectilinear grids

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import xarray as xr
import xesmf as xe

# %% [markdown]
# ## Prepare data

# %% [markdown]
# ### Input data

# %% [markdown]
# We regrid xarray's built-in demo data. This data is also used by [xarray plotting tutorial](http://xarray.pydata.org/en/stable/plotting.html).

# %%
ds = xr.tutorial.load_dataset('air_temperature')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 62.5 60.0 57.5 55.0 52.5 ...
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 210.0 212.5 215.0 217.5 ...
#   * time     (time) datetime64[ns] 2013-01-01T00:02:06.757437440 ...
# Data variables:
#     air      (time, lat, lon) float64 241.2 242.5 243.5 244.0 244.1 243.9 ...
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %% [markdown]
# It is the air temperature data over US with 2920 time frames. Let's plot the first frame:

# %%
dr = ds['air']  # extract an DataArray

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
dr.isel(time=0).plot.pcolormesh(ax=ax, vmin=230, vmax=300);
ax.coastlines();

# %% [markdown]
# ### Input grid

# %% [markdown]
# Its grid resolution is $2.5^\circ \times 2.5^\circ$:

# %%
ds['lat'].values, ds['lon'].values
# Out:
# (array([ 75. ,  72.5,  70. ,  67.5,  65. ,  62.5,  60. ,  57.5,  55. ,
#          52.5,  50. ,  47.5,  45. ,  42.5,  40. ,  37.5,  35. ,  32.5,
#          30. ,  27.5,  25. ,  22.5,  20. ,  17.5,  15. ], dtype=float32),
#  array([ 200. ,  202.5,  205. ,  207.5,  210. ,  212.5,  215. ,  217.5,
#          220. ,  222.5,  225. ,  227.5,  230. ,  232.5,  235. ,  237.5,
#          240. ,  242.5,  245. ,  247.5,  250. ,  252.5,  255. ,  257.5,
#          260. ,  262.5,  265. ,  267.5,  270. ,  272.5,  275. ,  277.5,
#          280. ,  282.5,  285. ,  287.5,  290. ,  292.5,  295. ,  297.5,
#          300. ,  302.5,  305. ,  307.5,  310. ,  312.5,  315. ,  317.5,
#          320. ,  322.5,  325. ,  327.5,  330. ], dtype=float32))

# %% [markdown]
# ### Output grid

# %% [markdown]
# Say we want to downsample it to $0.25^\circ \times 0.5^\circ$. Just define the output grid as an xarray `Dataset`:

# %%
ds_out = xr.Dataset({'lat': (['lat'], np.arange(15, 75.01, 0.25)),
                     'lon': (['lon'], np.arange(200, 330.01, 0.5)),
                    }
                   )
ds_out
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 241, lon: 261)
# Coordinates:
#   * lat      (lat) float64 15.0 15.25 15.5 15.75 16.0 16.25 16.5 16.75 17.0 ...
#   * lon      (lon) float64 200.0 200.5 201.0 201.5 202.0 202.5 203.0 203.5 ...
# Data variables:
#     *empty*

# %% [markdown]
# ## Perform regridding

# %% [markdown]
# Make a regridder by `xe.Regridder(grid_in, grid_out, method)`. `grid` is just an xarray `DataSet` containing `lat` and `lon` values. In most cases, `'bilinear'` should be good enough. For other methods see [Comparison of 5 regridding algorithms](./Compare_algorithms.ipynb).

# %%
regridder = xe.Regridder(ds, ds_out, 'bilinear')
regridder  # print basic regridder information.
# Out:
# Create weight file: bilinear_25x53_241x261.nc
# xESMF Regridder
# Regridding algorithm:       bilinear
# Weight filename:            bilinear_25x53_241x261.nc
# Reuse pre-computed weights? False
# Input grid shape:           (25, 53)
# Output grid shape:          (241, 261)
# Output grid dimension name: ('lat', 'lon')
# Periodic in longitude?      False

# %% [markdown]
# The regridder says it can transform data from shape `(25, 53)` to shape `(241, 261)`.
#
# Regrid the `DataArray` is straightforward:

# %%
dr_out = regridder(dr)
dr_out
# Out:
# <xarray.DataArray 'air' (time: 2920, lat: 241, lon: 261)>
# array([[[ 296.29    ,    0.      , ...,    0.      ,  296.6     ],
#         [ 296.250991,  296.347386, ...,  296.509328,  296.459968],
#         ...,
#         [ 241.460059,  241.710292, ...,  238.032375,  238.670016],
#         [ 241.2     ,  241.462205, ...,  237.98036 ,  238.6     ]],
#
#        [[ 296.29    ,    0.      , ...,    0.      ,  296.6     ],
#         [ 296.280998,  296.454975, ...,  296.423187,  296.449966],
#         ...,
#         [ 242.250034,  242.369363, ...,  235.329657,  235.789998],
#         [ 242.1     ,  242.22131 , ...,  235.359671,  235.8     ]],
#
#        ...,
#        [[ 297.79    ,    0.      , ...,    0.      ,  295.19    ],
#         [ 297.639966,  297.767262, ...,  295.178632,  295.109982],
#         ...,
#         [ 246.200094,  246.01177 , ...,  244.559336,  244.739989],
#         [ 245.79    ,  245.593619, ...,  244.629364,  244.79    ]],
#
# ...

# %% [markdown]
# The horizontal shape is now `(241, 261)`, as expected. The regridding operation broadcasts over extra dimensions (`time` here), so there are still 2920 time frames.
#
# `lon` and `lat` coordinate values are updated accordingly, and the value of the extra dimension `time` is kept the same as input.

# %% [markdown]
# <div class="alert alert-info">
#
# **Note:** Extra dimensions must be on the left, i.e. `(time, lev, lat, lon)` is correct but `(lat, lon, time, lev)` would not work. Most data sets should have `(lat, lon)` on the right (being the fastest changing dimension in the memory). If not, use `DataArray.transpose` or `numpy.transpose` to preprocess the data.
#
# </div>

# %% [markdown]
# ## Check results on 2D map

# %% [markdown]
# The regridding result is consistent with the original data, with a much finer resolution:

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
dr_out.isel(time=0).plot.pcolormesh(ax=ax, vmin=230, vmax=300);
ax.coastlines();

# %% [markdown]
# ## Check broadcasting over extra dimensions

# %% [markdown]
# xESMF tracks coordinate values over extra dimensions, since horizontal regridding should not affect them.

# %%
dr_out['time']
# Out:
# <xarray.DataArray 'time' (time: 2920)>
# array(['2013-01-01T00:02:06.757437440', '2013-01-01T05:59:27.234179072',
#        '2013-01-01T11:56:47.710920704', ..., '2014-12-31T05:58:10.831327232',
#        '2014-12-31T11:55:31.308068864', '2014-12-31T18:02:01.540624384'], dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2013-01-01T00:02:06.757437440 ...
# Attributes:
#     standard_name:  time
#     long_name:      Time

# %%
# exactly the same as input
xr.testing.assert_identical(dr_out['time'], ds['time'])

# %% [markdown]
# We can plot the time series at a specific location, to make sure the broadcasting is correct:

# %%
plt.subplot(2,1,1)
dr.sel(lon=260, lat=40).plot()  # input data
plt.subplot(2,1,2)
dr_out.sel(lon=260, lat=40).plot()  # output data

# %% [markdown]
# ## Clean-up

# %% [markdown]
# xESMF saves the regridder to the current directory so you don't need to re-compute it next time (see [Save time by reusing regridder](./Reuse_regridder.ipynb)). If you don't need it anymore, you can just delete it:

# %%
regridder.clean_weight_file()  # regridder.c + TAB would bring-up the command
# Out:
# Remove file bilinear_25x53_241x261.nc
